# %%
import pandas as pd

# %%
df=pd.read_csv("COVID-19 Activity.csv")#,parse_dates=['REPORT_DATE'])
# Out:
# C:\Users\Kent\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME  \
# 0                                  0      Clarke             Alabama
# 1                                  0      Clarke             Alabama
# 2                                  0      Clarke             Alabama
# 3                                  0      Clarke             Alabama
# 4                                  0      Clarke             Alabama
# ...                              ...         ...                 ...
# 2578747                            0         NaN               Henan
# 2578748                            0         NaN                 NaN
# 2578749                            0         NaN                 NaN
# 2578750                            0         NaN                 NaN
# 2578751                            0         NaN                 NaN
#
#         REPORT_DATE CONTINENT_NAME            DATA_SOURCE_NAME  \
# 0        2020-01-22        America              New York Times
# ...

# %%
#drop
df.drop(['COUNTRY_ALPHA_3_CODE','COUNTRY_ALPHA_2_CODE','COUNTY_FIPS_NUMBER'],axis=1,inplace=True)
df
#plot
#geographic spread with time
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME  \
# 0                                  0      Clarke             Alabama
# 1                                  0      Clarke             Alabama
# 2                                  0      Clarke             Alabama
# 3                                  0      Clarke             Alabama
# 4                                  0      Clarke             Alabama
# ...                              ...         ...                 ...
# 2578747                            0         NaN               Henan
# 2578748                            0         NaN                 NaN
# 2578749                            0         NaN                 NaN
# 2578750                            0         NaN                 NaN
# 2578751                            0         NaN                 NaN
#
#         REPORT_DATE CONTINENT_NAME            DATA_SOURCE_NAME  \
# 0        2020-01-22        America              New York Times
# ...

# %%
df['month']=df['REPORT_DATE'].apply(lambda x:x[:7])

# %%
df.groupby("REPORT_DATE").count()
# Out:
#              PEOPLE_POSITIVE_CASES_COUNT  COUNTY_NAME  PROVINCE_STATE_NAME  \
# REPORT_DATE
# 2020-01-21                          3552         3276                 3333
# 2020-01-22                          3552         3276                 3333
# 2020-01-23                          3552         3276                 3333
# 2020-01-24                          3552         3276                 3333
# 2020-01-25                          3552         3276                 3333
# ...                                  ...          ...                  ...
# 2022-01-11                          3552         3276                 3333
# 2022-01-12                          3552         3276                 3333
# 2022-01-13                          3552         3276                 3333
# 2022-01-14                          3552         3276                 3333
# 2022-01-15                          3552         3276                 3333
#
# ...

# %%
df.groupby("COUNTRY_SHORT_NAME").count()
# Out:
#                     PEOPLE_POSITIVE_CASES_COUNT  COUNTY_NAME  \
# COUNTRY_SHORT_NAME
# Afghanistan                                 726            0
# Albania                                     726            0
# Algeria                                     726            0
# Andorra                                     726            0
# Angola                                      726            0
# ...                                         ...          ...
# Wallis and Futuna                           726            0
# West Bank and Gaza                          726            0
# Yemen                                       726            0
# Zambia                                      726            0
# Zimbabwe                                    726            0
#
#                     PROVINCE_STATE_NAME  REPORT_DATE  CONTINENT_NAME  \
# COUNTRY_SHORT_NAME
# Afghanistan                           0          726             726
# ...

# %%
us=df[df["COUNTRY_SHORT_NAME"]=="United States"]
us.head()
# Out:
#    PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME REPORT_DATE  \
# 0                            0      Clarke             Alabama  2020-01-22
# 1                            0      Clarke             Alabama  2020-01-23
# 2                            0      Clarke             Alabama  2020-01-24
# 3                            0      Clarke             Alabama  2020-01-25
# 4                            0      Clarke             Alabama  2020-01-26
#
#   CONTINENT_NAME DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT COUNTRY_SHORT_NAME  \
# 0        America   New York Times                       0      United States
# 1        America   New York Times                       0      United States
# 2        America   New York Times                       0      United States
# 3        America   New York Times                       0      United States
# 4        America   New York Times                       0      United States
#
# ...

# %%
us.groupby('month').sum()['PEOPLE_POSITIVE_NEW_CASES_COUNT']
# Out:
# month
# 2020-01           7
# 2020-02          63
# 2020-03      188391
# 2020-04      887297
# 2020-05      723544
# 2020-06      854019
# 2020-07     1918348
# 2020-08     1473788
# 2020-09     1217278
# 2020-10     1946272
# 2020-11     4406314
# 2020-12     6409480
# 2021-01     6196874
# 2021-02     2402486
# 2021-03     1854725
# 2021-04     1883488
# 2021-05      915538
# 2021-06      361852
# 2021-07     1378800
# 2021-08     4298065
# 2021-09     4141403
# 2021-10     2476063
# 2021-11     2586693
# 2021-12     6168569
# 2022-01    10787635
# Name: PEOPLE_POSITIVE_NEW_CASES_COUNT, dtype: int64

# %%
us[us['REPORT_DATE']=="2020-01"]
# Out:
# Empty DataFrame
# Columns: [PEOPLE_POSITIVE_CASES_COUNT, COUNTY_NAME, PROVINCE_STATE_NAME, REPORT_DATE, CONTINENT_NAME, DATA_SOURCE_NAME, PEOPLE_DEATH_NEW_COUNT, COUNTRY_SHORT_NAME, PEOPLE_POSITIVE_NEW_CASES_COUNT, PEOPLE_DEATH_COUNT, month]
# Index: []

# %%
for i in df['COUNTRY_SHORT_NAME'].value_counts().index:
    if i[0] in 'hH':
        print(i)
# Out:
# Haiti
# Holy See
# Honduras
# Hungary

# %%
for i in [0,6,8,9]:
    j=df.columns[i]
    print(j,":",sum(df[j]<0))
# Out:
# PEOPLE_POSITIVE_CASES_COUNT : 0
# PEOPLE_DEATH_NEW_COUNT : 9657
# PEOPLE_POSITIVE_NEW_CASES_COUNT : 34752
# PEOPLE_DEATH_COUNT : 0

# %%
df[df['PEOPLE_DEATH_NEW_COUNT']<0]
# Out:
#          PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME  \
# 153                              222      Clarke             Alabama
# 212                              927      Clarke             Alabama
# 676                             1089      Clarke             Alabama
# 801                             3150      Clarke             Alabama
# 1217                            1261        Clay             Alabama
# ...                              ...         ...                 ...
# 2566452                        15614  Washington            Maryland
# 2567658                        31513         NaN     South Australia
# 2569636                        83030         NaN                 NaN
# 2570944                         3438         NaN                 NaN
# 2574041                         3332         NaN                 NaN
#
#         REPORT_DATE CONTINENT_NAME            DATA_SOURCE_NAME  \
# 153      2020-06-23        America              New York Times
# ...

# %%
df.iloc[152:155,:]
# Out:
#      PEOPLE_POSITIVE_CASES_COUNT COUNTY_NAME PROVINCE_STATE_NAME REPORT_DATE  \
# 152                          218      Clarke             Alabama  2020-06-22
# 153                          222      Clarke             Alabama  2020-06-23
# 154                          231      Clarke             Alabama  2020-06-24
#
#     CONTINENT_NAME DATA_SOURCE_NAME  PEOPLE_DEATH_NEW_COUNT  \
# 152        America   New York Times                       1
# 153        America   New York Times                      -1
# 154        America   New York Times                       1
#
#     COUNTRY_SHORT_NAME  PEOPLE_POSITIVE_NEW_CASES_COUNT  PEOPLE_DEATH_COUNT  \
# 152      United States                                2                   5
# 153      United States                                4                   4
# 154      United States                                9                   5
#
#        month
# 152  2020-06
# 153  2020-06
# 154  2020-06

# %%
df.columns
# Out:
# Index(['PEOPLE_POSITIVE_CASES_COUNT', 'COUNTY_NAME', 'PROVINCE_STATE_NAME',
#        'REPORT_DATE', 'CONTINENT_NAME', 'DATA_SOURCE_NAME',
#        'PEOPLE_DEATH_NEW_COUNT', 'COUNTRY_SHORT_NAME',
#        'PEOPLE_POSITIVE_NEW_CASES_COUNT', 'PEOPLE_DEATH_COUNT', 'month'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2578752 entries, 0 to 2578751
# Data columns (total 11 columns):
#  #   Column                           Dtype
# ---  ------                           -----
#  0   PEOPLE_POSITIVE_CASES_COUNT      int64
#  1   COUNTY_NAME                      object
#  2   PROVINCE_STATE_NAME              object
#  3   REPORT_DATE                      object
#  4   CONTINENT_NAME                   object
#  5   DATA_SOURCE_NAME                 object
#  6   PEOPLE_DEATH_NEW_COUNT           int64
#  7   COUNTRY_SHORT_NAME               object
#  8   PEOPLE_POSITIVE_NEW_CASES_COUNT  int64
#  9   PEOPLE_DEATH_COUNT               int64
#  10  month                            object
# dtypes: int64(4), object(7)
# memory usage: 216.4+ MB
